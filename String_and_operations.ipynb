# %%
# # Break : we use this when we want to stop a condition in middle 
# for i in range(1, 10):
#     if i == 5:
#         break
#     print(i)

# real time example 
for attempt in range(3):
    pin = input("Enter PIN: ")

    if pin == "1234":
        print("Access granted")
        break
    else:
        print("Wrong PIN")
# Out:
# Enter PIN:  1234
# Access granted

# %%
# # continue :  we use this to check a condition in the middle , but still continue the operation 

# for i in range(1, 10):
#     if i == 5:
#         continue
#     print(i)

# real time examplle 
ages = [12, 18, -5, 25, 0, 30]

for age in ages:
    if age <= 0:
        continue
    print("Valid age:", age)
# Out:
# Valid age: 12
# Valid age: 18
# Valid age: 25
# Valid age: 30

# %%
# strings : collection of chatacters is called a string 
# types of strings
a = "Hello"
b = 'World'
c = """Multi line
string example"""

# %%
# 1. string concatenation 
a='hello'
b='world'
a+b
# Out:
# 'helloworld'

# %%
# string properties ---------------> 1. Immutable --> once a string is created yoiu cannot replace the value 
s='hello world'

s[1]=l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 # string properties ---------------> 1. Immutable --> once a string is created yoiu cannot replace the value
#       2 s='hello world'
# ----> 4 s[1]=l
#
# NameError: name 'l' is not defined

# %%
# but you can concatenete 
s=s+'k'
print(s)
# Out:
# hello worldkk

# %%
# Index slicing # very important 

s[:]    #---------> prints wole strong
# Out:
# 'hello worldkk'

# %%
s[0:]  #---> start with zero go until end
# Out:
# 'hello worldkk'

# %%
s[:5]   #-------> starts with first point and goes 5 characters, including white space
# Out:
# 'hello'

# %%
s[-5]   #----------- starts counting form last index, with starting number -1 , not zero
# Out:
# 'r'

# %%
s[::3]    # steo size starts with forst character, keeps steeping 3 characters
# Out:
# 'hlwlk'

# %%
s[::-1]   #---------> prints the reversed string ---> it coutns from -1 to end of string automatically
# Out:
# 'kkdlrow olleh'

# %%
# string operations --> s.upper,s.lower, s.split,count(),locate(),find(),expand tabs 
s.upper()
# Out:
# 'HELLO WORLDKK'

# %%
s.lower()
# Out:
# 'hello worldkk'

# %%
#s.split()
s.split('kk')
# Out:
# ['hello world', '']

# %%
s.count('o') # you put in brackets, which chareacter is repeating in string
# Out:
# 2

# %%
s.find('k')  #--> gives the index number
# Out:
# 11

# %%
text = "Hello\tWorld"
print(text.expandtabs())
# Out:
# Hello   World

# %%
# see if  a string is alpha numeric 
s='1tarivaadu'
s.isalnum()
# Out:
# True

# %%
# see if a  string is lower 
s.islower()
# Out:
# True

# %%
# see if the string is upper 

s.isupper()
# Out:
# False

# %%
s.istitle() #--> checks if first index value is capital or no
# Out:
# False

# %%
s1='Hello'
s1.istitle()
# Out:
# True

# %%
s.partition('r')   #------> this is a regular expression
# Out:
# ('1ta', 'r', 'ivaadu')

# %%
 s1.endswith('o')    # checks if the last charatcer ends woth one we  put in bracktes
# Out:
# True
