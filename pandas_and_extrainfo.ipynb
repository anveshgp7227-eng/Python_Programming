# %%
import pandas as pd 

data = {
    "name": ['alice', 'bob', 'charlie'],
    "marks": [85, 90, 95]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       name  marks
# 0    alice     85
# 1      bob     90
# 2  charlie     95

# %%
#working directory commands 
os.getcwd()
os.listdir()

# %%
#try and except blok 
try:
    with open(r"C:\Users\Leo\RUCHIK\file.txt", "r") as f:
        print(f.read())

except FileNotFoundError:
    print("File not found!")

# %%
#database connector 
import sqlite3

conn = sqlite3.connect("mydatabase.db")
cursor = conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS students (
    id INTEGER PRIMARY KEY,
    name TEXT,
    marks INTEGER
)
""")

cursor.execute("INSERT INTO students (name, marks) VALUES (?, ?)", 
               ("Bob", 85))

conn.commit()

cursor.execute("SELECT * FROM students")
print(cursor.fetchall())

conn.close()
# Out:
# [(1, 'Bob', 85)]

# %%
#data visualixation
